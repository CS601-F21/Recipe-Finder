# %%
import json
import pymongo

# %%
#reading configs
with open('config.json') as json_file:
    config = json.load(json_file)

username = config['username']
password = config['password']
database = config['database']

# %%
#connecting to db
uri = "mongodb+srv://" +username+":"+password+"@"+database+".tjeuf.mongodb.net/RecipeSearch?retryWrites=true&w=majority"
client = pymongo.MongoClient("mongodb+srv://spareek:12345@recipesearch.tjeuf.mongodb.net/RecipeSearch?retryWrites=true&w=majority")
db = client.Recipes
recipe_collection = db.Recipe

# %%
sampledata = recipe_collection.find({})
unclean_item = recipe_collection.find( { "name": "Two-Tone Chocolate Pudding Cups" } )

search_ingredients = set()
for s in unclean_item:
    for ing in s['ingredients']:
        search_ingredients.add(ing)
# # clean_item = unclean_item['item']
# print(type(items))
# for i in unclean_item:
#     print(type(i))

# %%
search_ingredients = list(search_ingredients)
print(search_ingredients)
search_ingredients = ['milk', 'potatoes', 'salt', 'butter']
# Out:
# ['potatoes']

# %%
cursor = recipe_collection.find({ "ingredients": {"$in": search_ingredients } }
                         , {"name" : 1, "_id" : 0, "ingredients" : 1, "ingredient_quantity" : 1})

# %%
cursor = recipe_collection.find({"ingredients": {"$all": search_ingredients }})
all_recipes = list(cursor)
# print(all_recipes[0])

# %%
recipes_to_make = []
print(len(all_recipes))
# print(all_recipes)
# Out:
# 216

# %%
for r in all_recipes:
    allPresent = True
    rIngredients = set(r['ingredients'])
    print(r['name'])
    print(rIngredients)
    print('-----------')
#     if (len(rIngredients) == len(search_ingredients)):
#         print(r['name'])
#         print(rIngredients)
#         print('-----------')
# Out:
# Potato English Muffins
# {'leavening agents', 'salt', 'butter', 'milk', 'spices', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'onions', 'oil', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Slow Cooker Potatoes Au Gratin by Kim
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Creamed Potatoes
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Chocolate Monkey Bread
# {'candies', 'chocolate chip', 'water', 'vanilla extract', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'cocoa', 'potatoes'}
# -----------
# Wheat Rolls
# {'orange juice', 'water', 'leavening agents', 'salt', 'butter', 'milk', 'honey', 'wheat flour', 'potatoes'}
# -----------
# Creamy Dreamy Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Easy Cream of Potato Soup
# {'onions', 'soup', 'butter', 'salt', 'milk', 'spices', 'dill weed', 'wheat flour', 'potatoes'}
# -----------
# Cinderella's Royal Table Breakfast Potatoes
# {'onions', 'bacon', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Golden Potato Soup
# {'cream', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'chives', 'wheat flour', 'potatoes'}
# -----------
# Creamy Cheesy Veggie Soup
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'corn', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Potato Fudge
# {'chocolate chip', 'vanilla extract', 'salt', 'butter', 'milk', 'sugars', 'syrups', 'potatoes'}
# -----------
# King Arthur Flour's Pain De Mie - Perfect Sandwich Loaf
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Potato Bread for Bread Machine
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'potatoes', 'wheat flours'}
# -----------
# Creamy Onion & Garlic Mashed Potatoes
# {'onions', 'cream', 'oil', 'salt', 'butter', 'milk', 'spices', 'salad dressing', 'potatoes'}
# -----------
# Nana Hassard's Original Scalloped Potatoes
# {'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Cranberry Mashed Potatoes
# {'parsley', 'salt', 'butter', 'milk', 'spices', 'potatoes', 'cranberries'}
# -----------
# Potato Chive Bread (bread Machine)
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'chives', 'potatoes', 'wheat flours'}
# -----------
# Irish Potato Scones
# {'leavening agents', 'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Hearty Golden Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'chives', 'wheat flour', 'potatoes'}
# -----------
# Best Ever Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Dill Mashed Potatoes - Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'dill weed', 'potatoes'}
# -----------
# Crispy Italian Potato Scallop
# {'delallo', 'onions', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Potato Water Bread (Bread Machine)
# {'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes', 'wheat flours'}
# -----------
# Butter Roll-ups
# {'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes', 'wheat flours'}
# -----------
# Great Potato Soup Recipe
# {'onions', 'water', 'salt', 'butter', 'milk', 'spices', 'celery', 'wheat flour', 'mustard', 'potatoes'}
# -----------
# Cinnamon Rolls
# {'cream', 'water', 'vanilla extract', 'leavening agents', 'salt', 'butter', 'milk', 'spices', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Crock Pot Cheddar Mashed Potatoes
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Lover Boys Scalloped Potatoes
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Colcannon
# {'cabbage', 'onions', 'water', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Sweet Corn, Lima Bean and Lobster Shepherd's Pie
# {'cream', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Red Potato Colcannon
# {'onions', 'cabbage', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Southern Pan Fried Chicken
# {'bacon', 'cornstarch', 'water', 'lard', 'salt', 'butter', 'milk', 'chicken', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Potato Lefse
# {'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes With Bacon and Blue Cheese
# {'bacon', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Make-Ahead Ranch Mashed Potatoes
# {'cream', 'water', 'salt', 'butter', 'milk', 'salad dressing', 'potatoes'}
# -----------
# Baked Potatoes With Chees Recipe
# {'water', 'salt', 'butter', 'milk', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes
# {'parsley', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Just Good Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Mashed Red Potatoes With Horseradish
# {'horseradish', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Tomato Chowder
# {'onions', 'water', 'sauce', 'parsley', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'wheat flour', 'mustard', 'tomatoes', 'potatoes'}
# -----------
# Dill and Potato Cakes
# {'salt', 'butter', 'milk', 'dill weed', 'wheat flour', 'potatoes'}
# -----------
# White Wheat Bread Machine Sandwich Bread
# {'orange juice', 'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Crock Pot Mashed Potatoes
# {'water', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Pat's Scalloped Potatoes Supreme
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Buttermilk Mashed Potatoes
# {'oil', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Creamed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Potato Gratin With Cream and Fresh Herbs
# {'cream', 'salt', 'butter', 'milk', 'spices', 'chives', 'potatoes'}
# -----------
# Crock Pot Potato Dill Soup
# {'onions', 'water', 'soup', 'butter', 'salt', 'milk', 'spices', 'celery', 'carrots', 'dill weed', 'potatoes'}
# -----------
# Creamy Mashed Potatoes Microwaved
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Scalloped Potatoes with Herbed Cheese
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Potato Gratin with Chevre Recipe
# {'cream', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Browned Butter and Hazelnut Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'yogurt', 'nuts', 'potatoes'}
# -----------
# Scalloped Potatoes (Curdle Free)
# {'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Ma's Delmonico Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'mustard', 'wheat flour', 'potatoes'}
# -----------
# Ranch Mashed Potatoes
# {'onions', 'cream', 'salt', 'butter', 'milk', 'spices', 'dill weed', 'potatoes'}
# -----------
# Home-Style Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Two Cheese Potato Gratin
# {'salt', 'butter', 'milk', 'cheese', 'mustard', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Montreal Steak Seasoned Mashed Potatoes
# {'bacon', 'la flor', 'salt', 'butter', 'milk', 'cheese', 'potatoes'}
# -----------
# Creamy Ancho Chili Mashed Potatoes
# {'onions', 'cream', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Celeriac Mash
# {'salt', 'butter', 'milk', 'celery', 'potatoes'}
# -----------
# Double-Onion Smashed Potatoes
# {'fresh red onions', 'parsley', 'salt', 'butter', 'milk', 'shallots', 'spices', 'potatoes'}
# -----------
# Cream Turkey on Mashed Potatoes
# {'onions', 'shortening', 'salt', 'butter', 'milk', 'spices', 'ground turkey', 'wheat flour', 'potatoes'}
# -----------
# Cheddar Chowder
# {'onions', 'water', 'salt', 'soup', 'butter', 'milk', 'spices', 'celery', 'cheese', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# High Braes Retreat Scalloped Potatoes
# {'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes & Cauliflower With Ginger Scallion Pesto
# {'sauce', 'cauliflower', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Buttermilk Potato Bread ( Bread Machine)
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Cream Cheese Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'cheese', 'potatoes'}
# -----------
# Buttermilk-Parsley Spuds With Bacon Indeed!
# {'onions', 'bacon', 'oil', 'water', 'parsley', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Champ
# {'onions', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Soft and Fluffy White Bread
# {'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Quintessential Pecan Sticky Buns
# {'alcoholic beverage', 'water', 'leavening agents', 'syrup', 'salt', 'butter', 'milk', 'spices', 'sugars', 'wheat flour', 'nuts', 'potatoes'}
# -----------
# Tex Mex Carrot Casserole
# {'oil', 'sauce', 'salt', 'butter', 'milk', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Scalloped Potatoes For Fifty Recipe
# {'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# scollop potatoes via grill
# {'bacon', 'cream', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Homemade Wonder Bread
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Blue Cheese Mashed Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Potato Lefse
# {'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Broccoli Cheddar Mashed Potatoes
# {'cream', 'broccoli', 'salt', 'butter', 'milk', 'cheese', 'spices', 'peppers', 'potatoes'}
# -----------
# Berner Rosti - Rosti With Bacon
# {'bacon', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Scalloped Potatoes Done in the Microwave
# {'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Whipped Celery Potatoes
# {'onions', 'water', 'salt', 'butter', 'milk', 'spices', 'celery', 'potatoes'}
# -----------
# Potato and Mushroom Chowder Crockpot
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'wheat flour', 'potatoes', 'mushrooms'}
# -----------
# Hearty Potato and Sausage Chowder
# {'pork sausage', 'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Microwave Simple Scalloped Potatoes Recipe
# {'onions', 'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Rumbledethumps
# {'cabbage', 'broccoli', 'salt', 'butter', 'leeks', 'cheese', 'milk', 'spices', 'mustard', 'potatoes'}
# -----------
# Something Special Mashed Potatoes
# {'water', 'salt', 'butter', 'milk', 'sugars', 'potatoes'}
# -----------
# Cinnamon Raisin Swirl Bread
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'spices', 'sugars', 'wheat flour', 'raisins', 'potatoes'}
# -----------
# Mashed Potatoes With Ranch Dressing
# {'cream', 'parsley', 'salt', 'butter', 'milk', 'spices', 'chives', 'salad dressing', 'potatoes'}
# -----------
# Baked Creamy Potato Casserole
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Scalloped Potatoes With Cheese Recipe
# {'bread crumbs', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Old-Fashioned Potato-Beef Casserole
# {'onions', 'delallo', 'salt', 'butter', 'beef', 'milk', 'spices', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Creamy Onion And Potato Scallops Recipe
# {'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes with Chives
# {'salt', 'butter', 'milk', 'spices', 'chives', 'potatoes'}
# -----------
# Mashed Potatoes With Corn & Cheese
# {'bacon', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'corn', 'potatoes'}
# -----------
# Cheeseburger Soup
# {'onions', 'cream', 'soup', 'butter', 'beef', 'milk', 'spices', 'celery', 'cheese', 'carrots', 'wheat flour', 'salt', 'potatoes'}
# -----------
# Make Ahead Mashed Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Cinderella's Au Gratin Potatoes
# {'onions', 'bacon', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Hamburger Stew
# {'onions', 'salt', 'butter', 'beef', 'milk', 'carrots', 'wheat flour', 'tomatoes', 'potatoes'}
# -----------
# Fresh Mushroom Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'wheat flour', 'potatoes', 'mushrooms'}
# -----------
# Ven's Scalloped Potatoes W/Cheese
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Smashed Cheddar Potatoes
# {'parsley', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Friendly Neighbor Bread (Bread Machine 1 Pound Loaf)
# {'leavening agents', 'salt', 'butter', 'milk', 'honey', 'wheat flour', 'potatoes', 'wheat flours'}
# -----------
# Paprika Potato Soup
# {'onions', 'parsley', 'salt', 'butter', 'milk', 'spices', 'celery', 'wheat flour', 'potatoes'}
# -----------
# Green Onion Champ
# {'onions', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'onions', 'parsley', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Mom's Potato Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'chives', 'wheat flour', 'potatoes'}
# -----------
# Old Fashioned Corn and Potato Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'spices', 'corn', 'wheat flour', 'potatoes'}
# -----------
# Warm Dill Potato Salad
# {'onions', 'salt', 'butter', 'milk', 'spices', 'dill weed', 'wheat flour', 'salad dressing', 'potatoes'}
# -----------
# Smashed Potatoes
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Slow Cooker Garlic Mashed Potatoes
# {'water', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Confetti Mashed Potatoes
# {'onions', 'parsley', 'salt', 'butter', 'milk', 'spices', 'carrots', 'salad dressing', 'potatoes'}
# -----------
# Make-Ahead Twice-Baked Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Home Style Scalloped Potatoes
# {'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Boxty
# {'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Cheeseburger Soup
# {'onions', 'cream', 'soup', 'butter', 'beef', 'cheese', 'spices', 'celery', 'milk', 'carrots', 'wheat flour', 'salt', 'potatoes'}
# -----------
# Cheesy Dried Potatoes
# {'water', 'salt', 'butter', 'milk', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Boxty
# {'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# V's Do-Ahead Slow Cooker Mashed Potatoes
# {'water', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Cheesy Veggie Chowder
# {'peas', 'cabbage', 'onions', 'sauce', 'parsley', 'soup', 'butter', 'milk', 'salt', 'spices', 'celery', 'corn', 'carrots', 'cheese', 'potatoes'}
# -----------
# Cream Of Potato Soup
# {'onions', 'parsley', 'soup', 'butter', 'salt', 'milk', 'spices', 'celery', 'wheat flour', 'potatoes'}
# -----------
# Down East Haddock Chowder
# {'onions', 'water', 'sauce', 'salt', 'butter', 'milk', 'spices', 'celery', 'potatoes'}
# -----------
# Homemade White Bread
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'potatoes', 'wheat flours'}
# -----------
# Baked Potatoes With Broccoli And Chee Recipe
# {'water', 'broccoli', 'salt', 'butter', 'milk', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Hearty Golden Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'chives', 'wheat flour', 'potatoes'}
# -----------
# Potatoes and Eggs
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'egg substitute', 'potatoes'}
# -----------
# Pain De Mie - French Pullman Bread (Abm)
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Cheesy Chicken Chowder
# {'onions', 'soup', 'salt', 'butter', 'milk', 'spices', 'celery', 'cheese', 'carrots', 'wheat flour', 'chicken', 'potatoes'}
# -----------
# Zaarite Doctored-Up Fake Mashed Potatoes
# {'water', 'soup', 'butter', 'salt', 'milk', 'spices', 'salad dressing', 'potatoes'}
# -----------
# KFC Mashed Potatoes
# {'margarine', 'water', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Potato & Dumpling Soup Recipe
# {'onions', 'parsley', 'soup', 'salt', 'butter', 'milk', 'spices', 'celery', 'potatoes'}
# -----------
# Tom's Perfect Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Cheesy Scalloped Potatoes
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Diced Potato Gratin
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Soft Grain Bread
# {'water', 'leavening agents', 'cereals', 'oats', 'salt', 'butter', 'milk', 'honey', 'wheat flour', 'potatoes', 'wheat flours'}
# -----------
# Wasabi Mashed Potatoes
# {'wasabi', 'salt', 'butter', 'milk', 'yogurt', 'potatoes'}
# -----------
# Pat's Au Gratin Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Ethiopian Mashed Potatoes
# {'oil', 'salt', 'butter', 'milk', 'sweet potato', 'spices', 'corn', 'potatoes'}
# -----------
# Potato Almond Patties Recipe
# {'onions', 'water', 'salt', 'butter', 'milk', 'wheat flour', 'nuts', 'potatoes'}
# -----------
# Very Easy Potato Bacon Soup
# {'onions', 'bacon', 'water', 'salt', 'butter', 'milk', 'spices', 'dill weed', 'potatoes'}
# -----------
# Alton Brown - Potato Leek Soup
# {'cream', 'soup', 'butter', 'salt', 'leeks', 'milk', 'spices', 'chives', 'potatoes'}
# -----------
# Potato Biscuits
# {'leavening agents', 'salt', 'butter', 'milk', 'honey', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Potato Soup
# {'onions', 'bacon', 'parsley', 'soup', 'butter', 'salt', 'milk', 'spices', 'celery', 'carrots', 'potatoes'}
# -----------
# Parmesan Mashed Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Midwest Chowder Soup Recipe
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'corn', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Cheddar Chowder
# {'onions', 'bacon', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Cheesy Sausage Soup
# {'pork sausage', 'onions', 'cream', 'soup', 'butter', 'milk', 'cheese', 'spices', 'celery', 'salt', 'carrots', 'potatoes'}
# -----------
# Instant Potato Norwegian Lefse
# {'water', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Potato Soup
# {'onions', 'cream', 'water', 'salt', 'butter', 'milk', 'spices', 'celery', 'potatoes'}
# -----------
# Party Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Delicious Potato and Sweet Potato Mash
# {'salt', 'butter', 'milk', 'sweet potato', 'sugars', 'spices', 'potatoes'}
# -----------
# Parsley Mashed Potatoes
# {'parsley', 'salt', 'butter', 'milk', 'potatoes'}
# -----------
# Cheeseburger Soup Recipe
# {'onions', 'cream', 'soup', 'butter', 'beef', 'cheese', 'spices', 'celery', 'milk', 'carrots', 'wheat flour', 'salt', 'potatoes'}
# -----------
# Dijon Smashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'chives', 'mustard', 'potatoes'}
# -----------
# Gluten-Free Bannock
# {'molasses', 'leavening agents', 'salt', 'butter', 'milk', 'currants', 'wheat flour', 'potatoes'}
# -----------
# Gwens Old-Fashioned Potato-Beef Casserole
# {'onions', 'bread crumbs', 'salt', 'butter', 'beef', 'milk', 'spices', 'cheese', 'wheat flour', 'potatoes'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Irish Style Potato-Chive Pancakes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'chives', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Rosemary Parmesan Scalloped Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Microwave Scallop Potatoes Recipe
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Skillet Scalloped Potatoes
# {'fresh red onions', 'parsley', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# French Onion Mashed Potatoes
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Potato Soup
# {'onions', 'bacon', 'cream', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Mashed Potatoes With Cumin-Lime Butter
# {'lime juice', 'salt', 'butter', 'milk', 'shallots', 'spices', 'potatoes'}
# -----------
# Golden Whipped Potatoes
# {'salt', 'butter', 'milk', 'spices', 'carrots', 'potatoes'}
# -----------
# Whipped Potatoes
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Best Cheesy Potato Soup Ever!
# {'onions', 'soup', 'butter', 'milk', 'salt', 'spices', 'celery', 'cheese', 'potatoes'}
# -----------
# Perfect Mashed Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Scarfies Smoked Fish Chowder
# {'onions', 'water', 'sauce', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'wheat flour', 'mustard', 'tomatoes', 'potatoes'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'onions', 'oil', 'salt', 'butter', 'milk', 'spices', 'sugars', 'potatoes'}
# -----------
# Horseradish Scalloped Potatoes
# {'onions', 'horseradish', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Potato Soup
# {'onions', 'bacon', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Dill and Potato Cakes
# {'salt', 'butter', 'milk', 'dill weed', 'wheat flour', 'potatoes'}
# -----------
# Lefse - Scandinavian Potato Flatbread
# {'leavening agents', 'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Golden Pull-Apart Butter Buns
# {'water', 'leavening agents', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Mashed potatoes
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Mashed Potatoes with Spinach
# {'salt', 'butter', 'milk', 'spinach', 'spices', 'potatoes'}
# -----------
# Cheesy Broccoli Potato Soup
# {'onions', 'sauce', 'broccoli', 'soup', 'butter', 'milk', 'cheese', 'salt', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Dill Potato Cakes
# {'salt', 'butter', 'milk', 'dill weed', 'wheat flour', 'potatoes'}
# -----------
# Lefse I
# {'water', 'salt', 'butter', 'milk', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Pressure Cooker Mashed Potatoes
# {'water', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Cheesy Broccoli Potato Soup
# {'onions', 'sauce', 'broccoli', 'soup', 'butter', 'milk', 'cheese', 'salt', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Garlic Cheese Rolls
# {'oil', 'water', 'leavening agents', 'salt', 'butter', 'milk', 'cheese', 'spices', 'sugars', 'wheat flour', 'potatoes'}
# -----------
# Green Onion Champ
# {'onions', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Bubble and Squeak
# {'bacon', 'salt', 'butter', 'milk', 'leeks', 'brussels sprouts', 'cheese', 'spices', 'potatoes'}
# -----------
# Potatismos (Swedish Mashed Potatoes)
# {'salt', 'butter', 'milk', 'spices', 'sugars', 'potatoes'}
# -----------
# Celtic Cookery Champ
# {'onions', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Mashed Potatoes Zip N Steam Style
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Boxty
# {'leavening agents', 'salt', 'butter', 'milk', 'wheat flour', 'potatoes'}
# -----------
# Easy Leftover Mashed Potato Soup
# {'onions', 'sauce', 'soup', 'butter', 'milk', 'salt', 'spices', 'potatoes'}
# -----------
# Creamed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'dill weed', 'potatoes'}
# -----------
# Classic Vichyssoise
# {'onions', 'cream', 'salt', 'butter', 'leeks', 'chicken', 'milk', 'potatoes'}
# -----------
# Tusken Raider Taters
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Scalloped Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Creamed Peas & New Potatoes Recipe
# {'peas', 'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Crock Pot No-Fuss Potato Soup
# {'onions', 'water', 'parsley', 'soup', 'butter', 'salt', 'milk', 'spices', 'celery', 'cheese', 'carrots', 'potatoes'}
# -----------
# Dilly Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'dill weed', 'potatoes'}
# -----------
# Mom's Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'cream', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Thanksgiving Mashed Potatoes
# {'cream', 'salt', 'butter', 'milk', 'cheese', 'potatoes'}
# -----------
# Peppery Horseradish Mashed Potatoes
# {'horseradish', 'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# Parmesan Mashed Potatoes
# {'salt', 'butter', 'milk', 'cheese', 'spices', 'potatoes'}
# -----------
# Scalloped Potatoes With Three Cheeses
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Make-Ahead Mashed Potatoes With Browned Butter
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
# World Class Mashed Potatoes
# {'milk', 'potatoes', 'salt', 'butter'}
# -----------
# Corn Mashed Potatoes
# {'oil', 'salt', 'butter', 'milk', 'sweet potato', 'spices', 'corn', 'potatoes'}
# -----------
# Corn Mashed Potatoes
# {'oil', 'salt', 'butter', 'milk', 'sweet potato', 'spices', 'corn', 'potatoes'}
# -----------
# Hearty Golden Chowder
# {'onions', 'water', 'salt', 'butter', 'milk', 'cheese', 'spices', 'celery', 'carrots', 'chives', 'wheat flour', 'potatoes'}
# -----------
# Carrot Potato Casserole
# {'onions', 'salt', 'butter', 'milk', 'cheese', 'spices', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Potato And Corn Chowder Recipe
# {'onions', 'bacon', 'water', 'salt', 'butter', 'milk', 'spices', 'corn', 'carrots', 'wheat flour', 'potatoes'}
# -----------
# Scalloped Potatoes Recipe
# {'onions', 'salt', 'butter', 'milk', 'spices', 'wheat flour', 'potatoes'}
# -----------
# Old-Fashioned Mashed Potatoes
# {'salt', 'butter', 'milk', 'spices', 'potatoes'}
# -----------
