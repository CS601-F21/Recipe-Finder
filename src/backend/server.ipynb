# %%
import json
import pymongo

# %%
#reading configs
with open(r'/home/shubham/JavaScript/side-project-shubham0831/config.json') as json_file:
    config = json.load(json_file)

username = config['username']
password = config['password']
database = config['database']

# %%
#connecting to db
uri = "mongodb+srv://" +username+":"+password+"@"+database+".tjeuf.mongodb.net/RecipeSearch?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
db = client.Recipes
recipe_collection = db.Recipe

# %%
sampledata = recipe_collection.find({})
unclean_item = recipe_collection.find( { "name": "Two-Tone Chocolate Pudding Cups" } )

search_ingredients = set()
for s in unclean_item:
    for ing in s['ingredients']:
        search_ingredients.add(ing)
# # clean_item = unclean_item['item']
# print(type(items))
# for i in unclean_item:
#     print(type(i))

# %%
search_ingredients = list(search_ingredients)
print(search_ingredients)
search_ingredients = ['milk', 'potatoes', 'salt', 'butter']
# Out:
# ['milk', 'chocolate chip', 'sugars', 'raspberries']

# %%
cursor = recipe_collection.find({ "ingredients": {"$in": search_ingredients } }
                         , {"name" : 1, "_id" : 0, "ingredients" : 1, "ingredient_quantity" : 1})

# %%
cursor = recipe_collection.find({"ingredients": {"$all": search_ingredients }})
all_recipes = list(cursor)
# print(all_recipes[0])

# %%
recipes_to_make = []
print(len(all_recipes))
# print(all_recipes)
# Out:
# 216

# %%
for r in all_recipes:
    allPresent = True
    rIngredients = set(r['ingredients'])
    print(r['name'])
    print(rIngredients)
    print('-----------')
#     if (len(rIngredients) == len(search_ingredients)):
#         print(r['name'])
#         print(rIngredients)
#         print('-----------')
# Out:
# Potato English Muffins
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'onions', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'oil'}
# -----------
# Slow Cooker Potatoes Au Gratin by Kim
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Creamed Potatoes
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Chocolate Monkey Bread
# {'wheat flour', 'salt', 'cocoa', 'milk', 'butter', 'sugars', 'candies', 'vanilla extract', 'potatoes', 'leavening agents', 'chocolate chip', 'water'}
# -----------
# Wheat Rolls
# {'wheat flour', 'salt', 'orange juice', 'milk', 'butter', 'potatoes', 'leavening agents', 'honey', 'water'}
# -----------
# Creamy Dreamy Mashed Potatoes
# {'cream', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Easy Cream of Potato Soup
# {'onions', 'soup', 'wheat flour', 'spices', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Cinderella's Royal Table Breakfast Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bacon'}
# -----------
# Golden Potato Soup
# {'wheat flour', 'spices', 'cream', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'chives', 'water'}
# -----------
# Creamy Cheesy Veggie Soup
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'corn', 'water', 'carrots'}
# -----------
# Potato Fudge
# {'salt', 'syrups', 'milk', 'butter', 'sugars', 'vanilla extract', 'potatoes', 'chocolate chip'}
# -----------
# King Arthur Flour's Pain De Mie - Perfect Sandwich Loaf
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Potato Bread for Bread Machine
# {'wheat flours', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Creamy Onion & Garlic Mashed Potatoes
# {'onions', 'cream', 'spices', 'salad dressing', 'salt', 'milk', 'butter', 'potatoes', 'oil'}
# -----------
# Nana Hassard's Original Scalloped Potatoes
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Cranberry Mashed Potatoes
# {'spices', 'cranberries', 'salt', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Potato Chive Bread (bread Machine)
# {'wheat flours', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'chives', 'water'}
# -----------
# Irish Potato Scones
# {'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'leavening agents'}
# -----------
# Hearty Golden Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'chives', 'water', 'carrots'}
# -----------
# Best Ever Mashed Potatoes
# {'cream', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Dill Mashed Potatoes - Mashed Potatoes
# {'cream', 'spices', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Crispy Italian Potato Scallop
# {'onions', 'salt', 'delallo', 'milk', 'butter', 'potatoes'}
# -----------
# Potato Water Bread (Bread Machine)
# {'wheat flours', 'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes'}
# -----------
# Butter Roll-ups
# {'wheat flours', 'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents'}
# -----------
# Great Potato Soup Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'mustard', 'butter', 'milk', 'potatoes', 'water'}
# -----------
# Cinnamon Rolls
# {'wheat flour', 'spices', 'cream', 'salt', 'milk', 'butter', 'sugars', 'vanilla extract', 'potatoes', 'leavening agents', 'water'}
# -----------
# Crock Pot Cheddar Mashed Potatoes
# {'onions', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'water'}
# -----------
# Lover Boys Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Colcannon
# {'onions', 'spices', 'salt', 'milk', 'butter', 'cabbage', 'potatoes', 'water'}
# -----------
# Sweet Corn, Lima Bean and Lobster Shepherd's Pie
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Red Potato Colcannon
# {'onions', 'spices', 'salt', 'milk', 'butter', 'cabbage', 'potatoes'}
# -----------
# Southern Pan Fried Chicken
# {'wheat flour', 'spices', 'bacon', 'cornstarch', 'salt', 'lard', 'milk', 'butter', 'potatoes', 'chicken', 'water'}
# -----------
# Potato Lefse
# {'wheat flour', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Potatoes With Bacon and Blue Cheese
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bacon'}
# -----------
# Make-Ahead Ranch Mashed Potatoes
# {'cream', 'salad dressing', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Baked Potatoes With Chees Recipe
# {'wheat flour', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'water'}
# -----------
# Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Just Good Mashed Potatoes
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Red Potatoes With Horseradish
# {'salt', 'milk', 'butter', 'potatoes', 'horseradish'}
# -----------
# Tomato Chowder
# {'onions', 'wheat flour', 'spices', 'sauce', 'salt', 'celery', 'milk', 'butter', 'cheese', 'mustard', 'potatoes', 'parsley', 'tomatoes', 'water'}
# -----------
# Dill and Potato Cakes
# {'wheat flour', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# White Wheat Bread Machine Sandwich Bread
# {'wheat flour', 'salt', 'orange juice', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Crock Pot Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Pat's Scalloped Potatoes Supreme
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Buttermilk Mashed Potatoes
# {'salt', 'milk', 'butter', 'potatoes', 'oil'}
# -----------
# Creamed Potatoes
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Potato Gratin With Cream and Fresh Herbs
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'chives'}
# -----------
# Crock Pot Potato Dill Soup
# {'onions', 'soup', 'spices', 'salt', 'dill weed', 'celery', 'milk', 'butter', 'potatoes', 'water', 'carrots'}
# -----------
# Creamy Mashed Potatoes Microwaved
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Scalloped Potatoes with Herbed Cheese
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Potato Gratin with Chevre Recipe
# {'cream', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Browned Butter and Hazelnut Mashed Potatoes
# {'nuts', 'spices', 'yogurt', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Scalloped Potatoes (Curdle Free)
# {'wheat flour', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Ma's Delmonico Potatoes
# {'wheat flour', 'spices', 'salt', 'mustard', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Ranch Mashed Potatoes
# {'onions', 'cream', 'spices', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Home-Style Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Two Cheese Potato Gratin
# {'wheat flour', 'salt', 'milk', 'mustard', 'butter', 'cheese', 'potatoes'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Montreal Steak Seasoned Mashed Potatoes
# {'la flor', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bacon'}
# -----------
# Creamy Ancho Chili Mashed Potatoes
# {'onions', 'cream', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Celeriac Mash
# {'salt', 'celery', 'milk', 'butter', 'potatoes'}
# -----------
# Double-Onion Smashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'fresh red onions', 'parsley', 'shallots'}
# -----------
# Cream Turkey on Mashed Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'shortening', 'ground turkey'}
# -----------
# Cheddar Chowder
# {'onions', 'soup', 'spices', 'wheat flour', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'water', 'carrots'}
# -----------
# High Braes Retreat Scalloped Potatoes
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Potatoes & Cauliflower With Ginger Scallion Pesto
# {'spices', 'sauce', 'salt', 'milk', 'cauliflower', 'butter', 'potatoes'}
# -----------
# Buttermilk Potato Bread ( Bread Machine)
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Cream Cheese Mashed Potatoes
# {'cream', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Buttermilk-Parsley Spuds With Bacon Indeed!
# {'onions', 'spices', 'water', 'salt', 'milk', 'butter', 'potatoes', 'parsley', 'oil', 'bacon'}
# -----------
# Champ
# {'onions', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Soft and Fluffy White Bread
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents'}
# -----------
# Quintessential Pecan Sticky Buns
# {'nuts', 'syrup', 'wheat flour', 'spices', 'alcoholic beverage', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Tex Mex Carrot Casserole
# {'wheat flour', 'sauce', 'salt', 'milk', 'butter', 'potatoes', 'oil', 'carrots'}
# -----------
# Scalloped Potatoes For Fifty Recipe
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# scollop potatoes via grill
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'bacon'}
# -----------
# Homemade Wonder Bread
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Blue Cheese Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Potato Lefse
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes'}
# -----------
# Broccoli Cheddar Mashed Potatoes
# {'cream', 'spices', 'peppers', 'salt', 'milk', 'butter', 'cheese', 'broccoli', 'potatoes'}
# -----------
# Berner Rosti - Rosti With Bacon
# {'salt', 'milk', 'butter', 'potatoes', 'bacon'}
# -----------
# Scalloped Potatoes Done in the Microwave
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Whipped Celery Potatoes
# {'onions', 'spices', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Potato and Mushroom Chowder Crockpot
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'mushrooms', 'water', 'carrots'}
# -----------
# Hearty Potato and Sausage Chowder
# {'onions', 'wheat flour', 'spices', 'pork sausage', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Microwave Simple Scalloped Potatoes Recipe
# {'onions', 'wheat flour', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Rumbledethumps
# {'spices', 'salt', 'leeks', 'milk', 'mustard', 'butter', 'cheese', 'broccoli', 'cabbage', 'potatoes'}
# -----------
# Something Special Mashed Potatoes
# {'salt', 'milk', 'butter', 'sugars', 'potatoes', 'water'}
# -----------
# Cinnamon Raisin Swirl Bread
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'raisins', 'water'}
# -----------
# Mashed Potatoes With Ranch Dressing
# {'cream', 'spices', 'salad dressing', 'salt', 'milk', 'butter', 'chives', 'potatoes', 'parsley'}
# -----------
# Baked Creamy Potato Casserole
# {'onions', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Scalloped Potatoes With Cheese Recipe
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bread crumbs'}
# -----------
# Old-Fashioned Potato-Beef Casserole
# {'onions', 'wheat flour', 'spices', 'salt', 'delallo', 'milk', 'butter', 'cheese', 'potatoes', 'beef'}
# -----------
# Creamy Onion And Potato Scallops Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Potatoes with Chives
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'chives'}
# -----------
# Mashed Potatoes With Corn & Cheese
# {'bacon', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'corn', 'water'}
# -----------
# Cheeseburger Soup
# {'onions', 'soup', 'spices', 'wheat flour', 'cream', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'beef', 'carrots'}
# -----------
# Make Ahead Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Cinderella's Au Gratin Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bacon'}
# -----------
# Hamburger Stew
# {'onions', 'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'beef', 'tomatoes', 'carrots'}
# -----------
# Fresh Mushroom Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'mushrooms', 'water', 'carrots'}
# -----------
# Ven's Scalloped Potatoes W/Cheese
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Smashed Cheddar Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'parsley'}
# -----------
# Friendly Neighbor Bread (Bread Machine 1 Pound Loaf)
# {'wheat flours', 'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'leavening agents', 'honey'}
# -----------
# Paprika Potato Soup
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Green Onion Champ
# {'onions', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Mom's Potato Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'chives', 'water', 'carrots'}
# -----------
# Old Fashioned Corn and Potato Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'corn', 'water'}
# -----------
# Warm Dill Potato Salad
# {'onions', 'wheat flour', 'spices', 'salad dressing', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Smashed Potatoes
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Slow Cooker Garlic Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Confetti Mashed Potatoes
# {'onions', 'spices', 'salad dressing', 'salt', 'milk', 'butter', 'potatoes', 'parsley', 'carrots'}
# -----------
# Make-Ahead Twice-Baked Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Home Style Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Boxty
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Cheeseburger Soup
# {'onions', 'soup', 'spices', 'wheat flour', 'cream', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'beef', 'carrots'}
# -----------
# Cheesy Dried Potatoes
# {'wheat flour', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'water'}
# -----------
# Boxty
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes'}
# -----------
# V's Do-Ahead Slow Cooker Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Cheesy Veggie Chowder
# {'onions', 'soup', 'spices', 'sauce', 'salt', 'peas', 'celery', 'milk', 'butter', 'cheese', 'cabbage', 'potatoes', 'corn', 'parsley', 'carrots'}
# -----------
# Cream Of Potato Soup
# {'onions', 'soup', 'spices', 'wheat flour', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Down East Haddock Chowder
# {'onions', 'spices', 'sauce', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Homemade White Bread
# {'wheat flours', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Baked Potatoes With Broccoli And Chee Recipe
# {'wheat flour', 'salt', 'milk', 'butter', 'cheese', 'broccoli', 'potatoes', 'water'}
# -----------
# Hearty Golden Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'chives', 'water', 'carrots'}
# -----------
# Potatoes and Eggs
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'egg substitute'}
# -----------
# Pain De Mie - French Pullman Bread (Abm)
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Cheesy Chicken Chowder
# {'onions', 'soup', 'spices', 'wheat flour', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'chicken', 'carrots'}
# -----------
# Zaarite Doctored-Up Fake Mashed Potatoes
# {'soup', 'spices', 'salad dressing', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# KFC Mashed Potatoes
# {'salt', 'milk', 'butter', 'potatoes', 'water', 'margarine'}
# -----------
# Potato & Dumpling Soup Recipe
# {'onions', 'soup', 'spices', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Tom's Perfect Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Cheesy Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Diced Potato Gratin
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Soft Grain Bread
# {'wheat flours', 'oats', 'wheat flour', 'cereals', 'salt', 'milk', 'butter', 'potatoes', 'leavening agents', 'honey', 'water'}
# -----------
# Wasabi Mashed Potatoes
# {'yogurt', 'salt', 'milk', 'butter', 'wasabi', 'potatoes'}
# -----------
# Pat's Au Gratin Potatoes
# {'wheat flour', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Ethiopian Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'sweet potato', 'corn', 'oil'}
# -----------
# Potato Almond Patties Recipe
# {'nuts', 'onions', 'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Very Easy Potato Bacon Soup
# {'onions', 'bacon', 'spices', 'salt', 'dill weed', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Alton Brown - Potato Leek Soup
# {'soup', 'cream', 'spices', 'salt', 'leeks', 'milk', 'butter', 'potatoes', 'chives'}
# -----------
# Potato Biscuits
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'honey'}
# -----------
# Potato Soup
# {'onions', 'soup', 'spices', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'parsley', 'bacon', 'carrots'}
# -----------
# Parmesan Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Midwest Chowder Soup Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'corn', 'carrots'}
# -----------
# Mashed Potatoes
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Cheddar Chowder
# {'onions', 'wheat flour', 'spices', 'bacon', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'water', 'carrots'}
# -----------
# Cheesy Sausage Soup
# {'onions', 'soup', 'spices', 'cream', 'pork sausage', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'carrots'}
# -----------
# Instant Potato Norwegian Lefse
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'water'}
# -----------
# Potato Soup
# {'onions', 'cream', 'spices', 'salt', 'celery', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Party Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Delicious Potato and Sweet Potato Mash
# {'spices', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'sweet potato'}
# -----------
# Parsley Mashed Potatoes
# {'salt', 'milk', 'butter', 'potatoes', 'parsley'}
# -----------
# Cheeseburger Soup Recipe
# {'onions', 'soup', 'spices', 'wheat flour', 'cream', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'beef', 'carrots'}
# -----------
# Dijon Smashed Potatoes
# {'spices', 'salt', 'milk', 'mustard', 'butter', 'potatoes', 'chives'}
# -----------
# Gluten-Free Bannock
# {'molasses', 'wheat flour', 'salt', 'milk', 'butter', 'currants', 'potatoes', 'leavening agents'}
# -----------
# Gwens Old-Fashioned Potato-Beef Casserole
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'bread crumbs', 'beef'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Irish Style Potato-Chive Pancakes
# {'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'chives'}
# -----------
# Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Rosemary Parmesan Scalloped Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Microwave Scallop Potatoes Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Skillet Scalloped Potatoes
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'fresh red onions', 'parsley'}
# -----------
# French Onion Mashed Potatoes
# {'onions', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'water'}
# -----------
# Potato Soup
# {'onions', 'cream', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'bacon'}
# -----------
# Mashed Potatoes With Cumin-Lime Butter
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'lime juice', 'shallots'}
# -----------
# Golden Whipped Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'carrots'}
# -----------
# Whipped Potatoes
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Best Cheesy Potato Soup Ever!
# {'onions', 'soup', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Perfect Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Scarfies Smoked Fish Chowder
# {'onions', 'wheat flour', 'spices', 'sauce', 'salt', 'celery', 'mustard', 'butter', 'milk', 'cheese', 'potatoes', 'tomatoes', 'water'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'onions', 'spices', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'oil'}
# -----------
# Horseradish Scalloped Potatoes
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'horseradish'}
# -----------
# Potato Soup
# {'onions', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'bacon'}
# -----------
# Dill and Potato Cakes
# {'wheat flour', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Lefse - Scandinavian Potato Flatbread
# {'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'leavening agents'}
# -----------
# Golden Pull-Apart Butter Buns
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'leavening agents', 'water'}
# -----------
# Mashed potatoes
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Mashed Potatoes with Spinach
# {'spices', 'spinach', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Cheesy Broccoli Potato Soup
# {'onions', 'wheat flour', 'soup', 'spices', 'sauce', 'salt', 'milk', 'butter', 'cheese', 'broccoli', 'potatoes'}
# -----------
# Dill Potato Cakes
# {'wheat flour', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Lefse I
# {'wheat flour', 'salt', 'milk', 'butter', 'sugars', 'potatoes', 'water'}
# -----------
# Pressure Cooker Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'water'}
# -----------
# Cheesy Broccoli Potato Soup
# {'onions', 'wheat flour', 'soup', 'spices', 'sauce', 'salt', 'milk', 'butter', 'cheese', 'broccoli', 'potatoes'}
# -----------
# Garlic Cheese Rolls
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'sugars', 'cheese', 'potatoes', 'leavening agents', 'oil', 'water'}
# -----------
# Green Onion Champ
# {'onions', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Bubble and Squeak
# {'spices', 'brussels sprouts', 'salt', 'leeks', 'milk', 'butter', 'cheese', 'potatoes', 'bacon'}
# -----------
# Potatismos (Swedish Mashed Potatoes)
# {'spices', 'salt', 'milk', 'butter', 'sugars', 'potatoes'}
# -----------
# Celtic Cookery Champ
# {'onions', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Mashed Potatoes Zip N Steam Style
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Boxty
# {'wheat flour', 'salt', 'milk', 'butter', 'potatoes', 'leavening agents'}
# -----------
# Easy Leftover Mashed Potato Soup
# {'onions', 'soup', 'spices', 'sauce', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Creamed Potatoes
# {'cream', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Classic Vichyssoise
# {'onions', 'cream', 'salt', 'leeks', 'milk', 'butter', 'potatoes', 'chicken'}
# -----------
# Tusken Raider Taters
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Creamed Peas & New Potatoes Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'peas', 'milk', 'butter', 'potatoes'}
# -----------
# Crock Pot No-Fuss Potato Soup
# {'onions', 'soup', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'parsley', 'water', 'carrots'}
# -----------
# Dilly Mashed Potatoes
# {'cream', 'spices', 'salt', 'dill weed', 'milk', 'butter', 'potatoes'}
# -----------
# Mom's Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Scalloped Potatoes
# {'cream', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Thanksgiving Mashed Potatoes
# {'cream', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Peppery Horseradish Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'horseradish'}
# -----------
# Parmesan Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Scalloped Potatoes With Three Cheeses
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes'}
# -----------
# Make-Ahead Mashed Potatoes With Browned Butter
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# World Class Mashed Potatoes
# {'milk', 'butter', 'salt', 'potatoes'}
# -----------
# Corn Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'sweet potato', 'corn', 'oil'}
# -----------
# Corn Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes', 'sweet potato', 'corn', 'oil'}
# -----------
# Hearty Golden Chowder
# {'onions', 'wheat flour', 'spices', 'salt', 'celery', 'milk', 'butter', 'cheese', 'potatoes', 'chives', 'water', 'carrots'}
# -----------
# Carrot Potato Casserole
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'cheese', 'potatoes', 'carrots'}
# -----------
# Potato And Corn Chowder Recipe
# {'onions', 'bacon', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes', 'corn', 'water', 'carrots'}
# -----------
# Scalloped Potatoes Recipe
# {'onions', 'wheat flour', 'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------
# Old-Fashioned Mashed Potatoes
# {'spices', 'salt', 'milk', 'butter', 'potatoes'}
# -----------

# %%
from flask import Flask, redirect, url_for, request
app = Flask(__name__)
print(app)
# Out:
# <Flask '__main__'>

# %%
@app.route('/',methods = ['POST', 'GET'])
def login():
   if request.method == 'POST':
      user = request.form['nm']
      return redirect(url_for('success',name = user))
   else:
      user = request.args.get('nm')
      return redirect(url_for('success',name = user))
