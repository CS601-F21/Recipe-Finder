# %%
import json
import pymongo

# %%
#reading configs
with open(r'/home/shubham/JavaScript/side-project-shubham0831/config.json') as json_file:
    config = json.load(json_file)

username = config['username']
password = config['password']
database = config['database']

# %%
#connecting to db
uri = "mongodb+srv://" +username+":"+password+"@"+database+".tjeuf.mongodb.net/RecipeSearch?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
db = client.Recipes
recipe_collection = db.Recipe

# %%
sampledata = recipe_collection.find({})
unclean_item = recipe_collection.find( { "name": "Two-Tone Chocolate Pudding Cups" } )

search_ingredients = set()
for s in unclean_item:
    for ing in s['ingredients']:
        search_ingredients.add(ing)
# # clean_item = unclean_item['item']
# print(type(items))
# for i in unclean_item:
#     print(type(i))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_14547/2709054409.py in <module>
#       3
#       4 search_ingredients = set()
# ----> 5 for s in unclean_item:
#       6     for ing in s['ingredients']:
#       7         search_ingredients.add(ing)
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/cursor.py in next(self)
#    1236         if self.__empty:
#    1237             raise StopIteration
# -> 1238         if len(self.__data) or self._refresh():
#    1239             if self.__manipulate:
#    1240                 _db = self.__collection.database
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/cursor.py in _refresh(self)
#    1128
#    1129         if not self.__session:
# -> 1130             self.__session = self.__collection.database.client._ensure_session()
#    1131
#    1132         if self.__id is None:  # Query
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1933             # Don't make implicit sessions causally consistent. Applications
#    1934             # should always opt-in.
# -> 1935             return self.__start_session(True, causal_consistency=False)
#    1936         except (ConfigurationError, InvalidOperation):
#    1937             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1881
#    1882         # Raises ConfigurationError if sessions are not supported.
# -> 1883         server_session = self._get_server_session()
#    1884         opts = client_session.SessionOptions(**kwargs)
#    1885         return client_session.ClientSession(
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1919     def _get_server_session(self):
#    1920         """Internal: start or resume a _ServerSession."""
# -> 1921         return self._topology.get_server_session()
#    1922
#    1923     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/topology.py in get_server_session(self)
#     518             # Sessions are always supported in load balanced mode.
#     519             if not self._settings.load_balanced:
# --> 520                 session_timeout = self._check_session_support()
#     521             else:
#     522                 # Sessions never time out in load balanced mode.
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/topology.py in _check_session_support(self)
#     502                         None)
#     503             elif not self._description.readable_servers:
# --> 504                 self._select_servers_loop(
#     505                     readable_server_selector,
#     506                     self._settings.server_selection_timeout,
#
# ~/anaconda3/envs/sideproject/lib/python3.10/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     216             # No suitable servers.
#     217             if timeout == 0 or now > end_time:
# --> 218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
#     220                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: connection closed,connection closed,connection closed, Timeout: 30s, Topology Description: <TopologyDescription id: 619ed783f94c8ba38e214795, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('recipesearch-shard-00-00.tjeuf.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>, <ServerDescription ('recipesearch-shard-00-01.tjeuf.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>, <ServerDescription ('recipesearch-shard-00-02.tjeuf.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('connection closed')>]>

# %%
search_ingredients = list(search_ingredients)
print(search_ingredients)
search_ingredients = ['milk', 'potatoes', 'salt', 'butter']
# Out:
# ['milk', 'chocolate chip', 'sugars', 'raspberries']

# %%
cursor = recipe_collection.find({ "ingredients": {"$in": search_ingredients } }
                         , {"name" : 1, "_id" : 0, "ingredients" : 1, "ingredient_quantity" : 1})

# %%
cursor = recipe_collection.find({"ingredients": {"$all": search_ingredients }})
all_recipes = list(cursor)
# print(all_recipes[0])

# %%
recipes_to_make = []
print(len(all_recipes))
# print(all_recipes)
# Out:
# 216

# %%
for r in all_recipes:
    allPresent = True
    rIngredients = set(r['ingredients'])
    print(r['name'])
    print(rIngredients)
    print('-----------')
#     if (len(rIngredients) == len(search_ingredients)):
#         print(r['name'])
#         print(rIngredients)
#         print('-----------')
# Out:
# Potato English Muffins
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Slow Cooker Potatoes Au Gratin by Kim
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Creamed Potatoes
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Chocolate Monkey Bread
# {'candies', 'leavening agents', 'vanilla extract', 'potatoes', 'salt', 'chocolate chip', 'sugars', 'water', 'butter', 'wheat flour', 'cocoa', 'milk'}
# -----------
# Wheat Rolls
# {'leavening agents', 'potatoes', 'honey', 'salt', 'water', 'butter', 'wheat flour', 'orange juice', 'milk'}
# -----------
# Creamy Dreamy Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'milk'}
# -----------
# Easy Cream of Potato Soup
# {'potatoes', 'soup', 'salt', 'butter', 'wheat flour', 'onions', 'dill weed', 'milk', 'spices'}
# -----------
# Cinderella's Royal Table Breakfast Potatoes
# {'potatoes', 'cheese', 'salt', 'bacon', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Golden Potato Soup
# {'chives', 'potatoes', 'cheese', 'salt', 'cream', 'water', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Creamy Cheesy Veggie Soup
# {'potatoes', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices', 'corn'}
# -----------
# Potato Fudge
# {'potatoes', 'vanilla extract', 'salt', 'syrups', 'chocolate chip', 'sugars', 'butter', 'milk'}
# -----------
# King Arthur Flour's Pain De Mie - Perfect Sandwich Loaf
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Potato Bread for Bread Machine
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flours', 'milk'}
# -----------
# Creamy Onion & Garlic Mashed Potatoes
# {'potatoes', 'salad dressing', 'oil', 'salt', 'butter', 'onions', 'milk', 'cream', 'spices'}
# -----------
# Nana Hassard's Original Scalloped Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Cranberry Mashed Potatoes
# {'potatoes', 'salt', 'cranberries', 'butter', 'milk', 'spices', 'parsley'}
# -----------
# Potato Chive Bread (bread Machine)
# {'leavening agents', 'chives', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flours', 'milk'}
# -----------
# Irish Potato Scones
# {'leavening agents', 'potatoes', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Hearty Golden Chowder
# {'chives', 'potatoes', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Best Ever Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'milk'}
# -----------
# Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Dill Mashed Potatoes - Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'dill weed', 'milk', 'spices'}
# -----------
# Crispy Italian Potato Scallop
# {'potatoes', 'salt', 'delallo', 'butter', 'onions', 'milk'}
# -----------
# Potato Water Bread (Bread Machine)
# {'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'wheat flours', 'milk'}
# -----------
# Butter Roll-ups
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'wheat flours', 'milk'}
# -----------
# Great Potato Soup Recipe
# {'potatoes', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'mustard', 'onions', 'milk', 'spices'}
# -----------
# Cinnamon Rolls
# {'leavening agents', 'potatoes', 'vanilla extract', 'salt', 'cream', 'sugars', 'water', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Crock Pot Cheddar Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'water', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Lover Boys Scalloped Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Colcannon
# {'potatoes', 'salt', 'water', 'butter', 'cabbage', 'onions', 'milk', 'spices'}
# -----------
# Sweet Corn, Lima Bean and Lobster Shepherd's Pie
# {'potatoes', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Red Potato Colcannon
# {'potatoes', 'salt', 'butter', 'cabbage', 'onions', 'milk', 'spices'}
# -----------
# Southern Pan Fried Chicken
# {'potatoes', 'salt', 'bacon', 'water', 'cornstarch', 'chicken', 'wheat flour', 'butter', 'lard', 'milk', 'spices'}
# -----------
# Potato Lefse
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Mashed Potatoes With Bacon and Blue Cheese
# {'potatoes', 'cheese', 'salt', 'bacon', 'butter', 'milk', 'spices'}
# -----------
# Make-Ahead Ranch Mashed Potatoes
# {'potatoes', 'salad dressing', 'salt', 'cream', 'water', 'butter', 'milk'}
# -----------
# Baked Potatoes With Chees Recipe
# {'potatoes', 'cheese', 'salt', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices', 'parsley'}
# -----------
# Just Good Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Mashed Red Potatoes With Horseradish
# {'horseradish', 'potatoes', 'salt', 'butter', 'milk'}
# -----------
# Tomato Chowder
# {'potatoes', 'cheese', 'sauce', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'mustard', 'onions', 'milk', 'spices', 'parsley', 'tomatoes'}
# -----------
# Dill and Potato Cakes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'dill weed', 'milk'}
# -----------
# White Wheat Bread Machine Sandwich Bread
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'orange juice', 'milk'}
# -----------
# Crock Pot Mashed Potatoes
# {'potatoes', 'salt', 'water', 'butter', 'milk', 'spices'}
# -----------
# Pat's Scalloped Potatoes Supreme
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Buttermilk Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'butter', 'milk'}
# -----------
# Creamed Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Potato Gratin With Cream and Fresh Herbs
# {'chives', 'potatoes', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Crock Pot Potato Dill Soup
# {'potatoes', 'soup', 'salt', 'celery', 'water', 'butter', 'onions', 'carrots', 'dill weed', 'milk', 'spices'}
# -----------
# Creamy Mashed Potatoes Microwaved
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Scalloped Potatoes with Herbed Cheese
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Potato Gratin with Chevre Recipe
# {'potatoes', 'cheese', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Browned Butter and Hazelnut Mashed Potatoes
# {'potatoes', 'nuts', 'yogurt', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Scalloped Potatoes (Curdle Free)
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Ma's Delmonico Potatoes
# {'potatoes', 'cheese', 'salt', 'mustard', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Ranch Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'onions', 'dill weed', 'milk', 'spices'}
# -----------
# Home-Style Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Two Cheese Potato Gratin
# {'potatoes', 'cheese', 'salt', 'mustard', 'butter', 'wheat flour', 'milk'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Montreal Steak Seasoned Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'bacon', 'butter', 'milk', 'la flor'}
# -----------
# Creamy Ancho Chili Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'cream', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Celeriac Mash
# {'potatoes', 'salt', 'celery', 'butter', 'milk'}
# -----------
# Double-Onion Smashed Potatoes
# {'potatoes', 'salt', 'fresh red onions', 'butter', 'shallots', 'milk', 'spices', 'parsley'}
# -----------
# Cream Turkey on Mashed Potatoes
# {'ground turkey', 'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'shortening', 'milk', 'spices'}
# -----------
# Cheddar Chowder
# {'potatoes', 'soup', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# High Braes Retreat Scalloped Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Mashed Potatoes & Cauliflower With Ginger Scallion Pesto
# {'potatoes', 'salt', 'sauce', 'butter', 'milk', 'spices', 'cauliflower'}
# -----------
# Buttermilk Potato Bread ( Bread Machine)
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Cream Cheese Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'cream', 'butter', 'milk'}
# -----------
# Buttermilk-Parsley Spuds With Bacon Indeed!
# {'potatoes', 'oil', 'salt', 'bacon', 'water', 'butter', 'onions', 'milk', 'spices', 'parsley'}
# -----------
# Champ
# {'potatoes', 'salt', 'butter', 'onions', 'milk'}
# -----------
# Soft and Fluffy White Bread
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'milk'}
# -----------
# Quintessential Pecan Sticky Buns
# {'leavening agents', 'potatoes', 'nuts', 'salt', 'syrup', 'sugars', 'water', 'butter', 'wheat flour', 'alcoholic beverage', 'milk', 'spices'}
# -----------
# Tex Mex Carrot Casserole
# {'potatoes', 'oil', 'salt', 'sauce', 'butter', 'wheat flour', 'carrots', 'milk'}
# -----------
# Scalloped Potatoes For Fifty Recipe
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# scollop potatoes via grill
# {'potatoes', 'salt', 'cream', 'bacon', 'butter', 'milk', 'spices'}
# -----------
# Homemade Wonder Bread
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Blue Cheese Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Potato Lefse
# {'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'milk'}
# -----------
# Broccoli Cheddar Mashed Potatoes
# {'peppers', 'broccoli', 'potatoes', 'cheese', 'salt', 'butter', 'milk', 'cream', 'spices'}
# -----------
# Berner Rosti - Rosti With Bacon
# {'potatoes', 'salt', 'bacon', 'butter', 'milk'}
# -----------
# Scalloped Potatoes Done in the Microwave
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Whipped Celery Potatoes
# {'potatoes', 'salt', 'celery', 'water', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Potato and Mushroom Chowder Crockpot
# {'potatoes', 'mushrooms', 'salt', 'cheese', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Hearty Potato and Sausage Chowder
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices', 'pork sausage'}
# -----------
# Microwave Simple Scalloped Potatoes Recipe
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk'}
# -----------
# Rumbledethumps
# {'broccoli', 'potatoes', 'cheese', 'salt', 'mustard', 'butter', 'cabbage', 'milk', 'spices', 'leeks'}
# -----------
# Something Special Mashed Potatoes
# {'potatoes', 'salt', 'sugars', 'water', 'butter', 'milk'}
# -----------
# Cinnamon Raisin Swirl Bread
# {'leavening agents', 'potatoes', 'raisins', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Mashed Potatoes With Ranch Dressing
# {'chives', 'potatoes', 'salad dressing', 'salt', 'cream', 'butter', 'milk', 'spices', 'parsley'}
# -----------
# Baked Creamy Potato Casserole
# {'potatoes', 'cheese', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Scalloped Potatoes With Cheese Recipe
# {'bread crumbs', 'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Old-Fashioned Potato-Beef Casserole
# {'potatoes', 'beef', 'cheese', 'salt', 'delallo', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Creamy Onion And Potato Scallops Recipe
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Mashed Potatoes with Chives
# {'chives', 'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Mashed Potatoes With Corn & Cheese
# {'potatoes', 'cheese', 'salt', 'bacon', 'water', 'butter', 'milk', 'spices', 'corn'}
# -----------
# Cheeseburger Soup
# {'potatoes', 'beef', 'soup', 'cheese', 'salt', 'cream', 'celery', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Make Ahead Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Cinderella's Au Gratin Potatoes
# {'potatoes', 'cheese', 'salt', 'bacon', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Hamburger Stew
# {'potatoes', 'beef', 'salt', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'tomatoes'}
# -----------
# Fresh Mushroom Chowder
# {'potatoes', 'mushrooms', 'salt', 'cheese', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Ven's Scalloped Potatoes W/Cheese
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Smashed Cheddar Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices', 'parsley'}
# -----------
# Friendly Neighbor Bread (Bread Machine 1 Pound Loaf)
# {'leavening agents', 'potatoes', 'honey', 'salt', 'butter', 'wheat flour', 'wheat flours', 'milk'}
# -----------
# Paprika Potato Soup
# {'potatoes', 'salt', 'celery', 'butter', 'wheat flour', 'onions', 'milk', 'spices', 'parsley'}
# -----------
# Green Onion Champ
# {'potatoes', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Scalloped Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices', 'parsley'}
# -----------
# Mom's Potato Chowder
# {'chives', 'potatoes', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Old Fashioned Corn and Potato Chowder
# {'potatoes', 'salt', 'water', 'butter', 'wheat flour', 'onions', 'milk', 'spices', 'corn'}
# -----------
# Warm Dill Potato Salad
# {'potatoes', 'salad dressing', 'salt', 'butter', 'wheat flour', 'onions', 'dill weed', 'milk', 'spices'}
# -----------
# Smashed Potatoes
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Slow Cooker Garlic Mashed Potatoes
# {'potatoes', 'salt', 'water', 'butter', 'milk', 'spices'}
# -----------
# Confetti Mashed Potatoes
# {'potatoes', 'salad dressing', 'salt', 'butter', 'onions', 'carrots', 'milk', 'spices', 'parsley'}
# -----------
# Make-Ahead Twice-Baked Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Home Style Scalloped Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Boxty
# {'potatoes', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Cheeseburger Soup
# {'soup', 'beef', 'potatoes', 'cheese', 'salt', 'cream', 'celery', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Cheesy Dried Potatoes
# {'potatoes', 'cheese', 'salt', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Boxty
# {'potatoes', 'salt', 'sugars', 'butter', 'wheat flour', 'milk'}
# -----------
# V's Do-Ahead Slow Cooker Mashed Potatoes
# {'potatoes', 'salt', 'water', 'butter', 'milk', 'spices'}
# -----------
# Cheesy Veggie Chowder
# {'potatoes', 'soup', 'cheese', 'sauce', 'salt', 'celery', 'butter', 'cabbage', 'onions', 'carrots', 'peas', 'milk', 'spices', 'parsley', 'corn'}
# -----------
# Cream Of Potato Soup
# {'potatoes', 'soup', 'salt', 'celery', 'butter', 'wheat flour', 'onions', 'milk', 'spices', 'parsley'}
# -----------
# Down East Haddock Chowder
# {'potatoes', 'sauce', 'salt', 'celery', 'water', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Homemade White Bread
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flours', 'milk'}
# -----------
# Baked Potatoes With Broccoli And Chee Recipe
# {'broccoli', 'potatoes', 'cheese', 'salt', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Hearty Golden Chowder
# {'chives', 'potatoes', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Potatoes and Eggs
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices', 'egg substitute'}
# -----------
# Pain De Mie - French Pullman Bread (Abm)
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Cheesy Chicken Chowder
# {'potatoes', 'soup', 'cheese', 'salt', 'celery', 'butter', 'wheat flour', 'chicken', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Zaarite Doctored-Up Fake Mashed Potatoes
# {'soup', 'potatoes', 'salad dressing', 'salt', 'water', 'butter', 'milk', 'spices'}
# -----------
# KFC Mashed Potatoes
# {'potatoes', 'margarine', 'salt', 'water', 'butter', 'milk'}
# -----------
# Potato & Dumpling Soup Recipe
# {'soup', 'potatoes', 'salt', 'celery', 'butter', 'onions', 'milk', 'spices', 'parsley'}
# -----------
# Tom's Perfect Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Cheesy Scalloped Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Diced Potato Gratin
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Soft Grain Bread
# {'leavening agents', 'oats', 'potatoes', 'honey', 'salt', 'water', 'butter', 'wheat flour', 'wheat flours', 'cereals', 'milk'}
# -----------
# Wasabi Mashed Potatoes
# {'potatoes', 'salt', 'yogurt', 'butter', 'milk', 'wasabi'}
# -----------
# Pat's Au Gratin Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Ethiopian Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'sweet potato', 'butter', 'milk', 'spices', 'corn'}
# -----------
# Potato Almond Patties Recipe
# {'potatoes', 'nuts', 'salt', 'water', 'butter', 'wheat flour', 'onions', 'milk'}
# -----------
# Very Easy Potato Bacon Soup
# {'potatoes', 'salt', 'bacon', 'water', 'butter', 'onions', 'dill weed', 'milk', 'spices'}
# -----------
# Alton Brown - Potato Leek Soup
# {'chives', 'soup', 'potatoes', 'salt', 'butter', 'milk', 'cream', 'spices', 'leeks'}
# -----------
# Potato Biscuits
# {'leavening agents', 'potatoes', 'honey', 'salt', 'sugars', 'butter', 'wheat flour', 'milk'}
# -----------
# Potato Soup
# {'soup', 'potatoes', 'salt', 'bacon', 'celery', 'butter', 'onions', 'carrots', 'milk', 'spices', 'parsley'}
# -----------
# Parmesan Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Midwest Chowder Soup Recipe
# {'potatoes', 'cheese', 'salt', 'celery', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices', 'corn'}
# -----------
# Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Cheddar Chowder
# {'potatoes', 'cheese', 'salt', 'bacon', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Cheesy Sausage Soup
# {'soup', 'potatoes', 'cheese', 'salt', 'cream', 'celery', 'butter', 'onions', 'carrots', 'milk', 'spices', 'pork sausage'}
# -----------
# Instant Potato Norwegian Lefse
# {'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Potato Soup
# {'potatoes', 'salt', 'cream', 'celery', 'water', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Party Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Delicious Potato and Sweet Potato Mash
# {'potatoes', 'salt', 'sugars', 'sweet potato', 'butter', 'milk', 'spices'}
# -----------
# Parsley Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'parsley'}
# -----------
# Cheeseburger Soup Recipe
# {'soup', 'beef', 'potatoes', 'cheese', 'salt', 'cream', 'celery', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Dijon Smashed Potatoes
# {'chives', 'potatoes', 'salt', 'mustard', 'butter', 'milk', 'spices'}
# -----------
# Gluten-Free Bannock
# {'leavening agents', 'molasses', 'potatoes', 'salt', 'currants', 'butter', 'wheat flour', 'milk'}
# -----------
# Gwens Old-Fashioned Potato-Beef Casserole
# {'bread crumbs', 'potatoes', 'beef', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Mashed Potatoes - Basic Recipe
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Irish Style Potato-Chive Pancakes
# {'chives', 'potatoes', 'salt', 'cream', 'butter', 'milk', 'spices'}
# -----------
# Scalloped Potatoes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Rosemary Parmesan Scalloped Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Microwave Scallop Potatoes Recipe
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Skillet Scalloped Potatoes
# {'potatoes', 'salt', 'fresh red onions', 'butter', 'wheat flour', 'milk', 'spices', 'parsley'}
# -----------
# French Onion Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'water', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Potato Soup
# {'potatoes', 'salt', 'cream', 'bacon', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Mashed Potatoes With Cumin-Lime Butter
# {'potatoes', 'salt', 'lime juice', 'butter', 'shallots', 'milk', 'spices'}
# -----------
# Golden Whipped Potatoes
# {'potatoes', 'salt', 'butter', 'carrots', 'milk', 'spices'}
# -----------
# Whipped Potatoes
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Best Cheesy Potato Soup Ever!
# {'potatoes', 'soup', 'cheese', 'salt', 'celery', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Perfect Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Scarfies Smoked Fish Chowder
# {'potatoes', 'cheese', 'salt', 'sauce', 'celery', 'water', 'butter', 'wheat flour', 'mustard', 'onions', 'milk', 'spices', 'tomatoes'}
# -----------
# Caramelized Onion Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'sugars', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Horseradish Scalloped Potatoes
# {'horseradish', 'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Potato Soup
# {'potatoes', 'salt', 'bacon', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Dill and Potato Cakes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'dill weed', 'milk'}
# -----------
# Lefse - Scandinavian Potato Flatbread
# {'leavening agents', 'potatoes', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Golden Pull-Apart Butter Buns
# {'leavening agents', 'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Mashed potatoes
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Mashed Potatoes with Spinach
# {'potatoes', 'salt', 'butter', 'spinach', 'milk', 'spices'}
# -----------
# Cheesy Broccoli Potato Soup
# {'broccoli', 'soup', 'potatoes', 'cheese', 'sauce', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Dill Potato Cakes
# {'potatoes', 'salt', 'butter', 'wheat flour', 'dill weed', 'milk'}
# -----------
# Lefse I
# {'potatoes', 'salt', 'sugars', 'water', 'butter', 'wheat flour', 'milk'}
# -----------
# Pressure Cooker Mashed Potatoes
# {'potatoes', 'salt', 'water', 'butter', 'milk', 'spices'}
# -----------
# Cheesy Broccoli Potato Soup
# {'broccoli', 'soup', 'potatoes', 'cheese', 'sauce', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Garlic Cheese Rolls
# {'leavening agents', 'potatoes', 'oil', 'salt', 'cheese', 'sugars', 'water', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Green Onion Champ
# {'potatoes', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Bubble and Squeak
# {'potatoes', 'cheese', 'salt', 'bacon', 'butter', 'brussels sprouts', 'milk', 'spices', 'leeks'}
# -----------
# Potatismos (Swedish Mashed Potatoes)
# {'potatoes', 'salt', 'sugars', 'butter', 'milk', 'spices'}
# -----------
# Celtic Cookery Champ
# {'potatoes', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Mashed Potatoes Zip N Steam Style
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Boxty
# {'leavening agents', 'potatoes', 'salt', 'butter', 'wheat flour', 'milk'}
# -----------
# Easy Leftover Mashed Potato Soup
# {'potatoes', 'soup', 'sauce', 'salt', 'butter', 'onions', 'milk', 'spices'}
# -----------
# Creamed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'dill weed', 'milk'}
# -----------
# Classic Vichyssoise
# {'potatoes', 'salt', 'cream', 'butter', 'chicken', 'onions', 'milk', 'leeks'}
# -----------
# Tusken Raider Taters
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Scalloped Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Creamed Peas & New Potatoes Recipe
# {'potatoes', 'salt', 'butter', 'wheat flour', 'peas', 'onions', 'milk', 'spices'}
# -----------
# Crock Pot No-Fuss Potato Soup
# {'potatoes', 'soup', 'cheese', 'salt', 'celery', 'water', 'butter', 'onions', 'carrots', 'milk', 'spices', 'parsley'}
# -----------
# Dilly Mashed Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'dill weed', 'milk', 'spices'}
# -----------
# Mom's Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Scalloped Potatoes
# {'potatoes', 'salt', 'cream', 'butter', 'wheat flour', 'milk', 'spices'}
# -----------
# Thanksgiving Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'cream', 'butter', 'milk'}
# -----------
# Peppery Horseradish Mashed Potatoes
# {'horseradish', 'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Parmesan Mashed Potatoes
# {'potatoes', 'cheese', 'salt', 'butter', 'milk', 'spices'}
# -----------
# Scalloped Potatoes With Three Cheeses
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Make-Ahead Mashed Potatoes With Browned Butter
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------
# World Class Mashed Potatoes
# {'salt', 'milk', 'potatoes', 'butter'}
# -----------
# Corn Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'sweet potato', 'butter', 'milk', 'spices', 'corn'}
# -----------
# Corn Mashed Potatoes
# {'potatoes', 'oil', 'salt', 'sweet potato', 'butter', 'milk', 'spices', 'corn'}
# -----------
# Hearty Golden Chowder
# {'chives', 'potatoes', 'cheese', 'salt', 'celery', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Carrot Potato Casserole
# {'potatoes', 'cheese', 'salt', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices'}
# -----------
# Potato And Corn Chowder Recipe
# {'potatoes', 'salt', 'bacon', 'water', 'butter', 'wheat flour', 'onions', 'carrots', 'milk', 'spices', 'corn'}
# -----------
# Scalloped Potatoes Recipe
# {'potatoes', 'salt', 'butter', 'wheat flour', 'onions', 'milk', 'spices'}
# -----------
# Old-Fashioned Mashed Potatoes
# {'potatoes', 'salt', 'butter', 'milk', 'spices'}
# -----------

# %%
from flask import Flask, redirect, url_for, request
app = Flask(__name__)
print(app)
# Out:
# <Flask '__main__'>

# %%
@app.route('/',methods = ['POST', 'GET'])
def login():
   if request.method == 'POST':
      user = request.form['nm']
      return redirect(url_for('success',name = user))
   else:
      user = request.args.get('nm')
      return redirect(url_for('success',name = user))
